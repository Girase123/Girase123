# %%
import pandas as pd
import matplotlib.pyplot as plt

# Sample dataset
data = {
    'Name': ['Sharayu', 'Shipra', 'Vishal', 'Abhi', 'Neelu', 'Kavita'],
    'Gender': ['Female', 'Female', 'Male', 'Male', 'Female', 'Female'],  # Qualitative
    'Department': ['HR', 'IT', 'Finance', 'IT', 'HR', 'Finance'],    # Qualitative
    'Age': [21, 30, 35, 18, 32, 44],                                # Quantitative
    'Salary': [40000, 55000, 75000, 50000, 62000, 68000]            # Quantitative
}

df = pd.DataFrame(data)
df.head()
# Out:
#       Name  Gender Department  Age  Salary
# 0  Sharayu  Female         HR   21   40000
# 1   Shipra  Female         IT   30   55000
# 2   Vishal    Male    Finance   35   75000
# 3     Abhi    Male         IT   18   50000
# 4    Neelu  Female         HR   32   62000

# %%
# --- QUALITATIVE ANALYSIS ---
print("Qualitative Analysis:")
print(df['Gender'].value_counts())      # Frequency of categories
print(df['Department'].value_counts())  # Frequency of departments

# Bar chart for Gender distribution
df['Gender'].value_counts().plot(kind='bar', color=['red', 'lightblue'])
plt.title("Gender Distribution")
plt.xlabel("Gender")
plt.ylabel("Count")
plt.show()
# Out:
# Qualitative Analysis:
# Gender
# Female    4
# Male      2
# Name: count, dtype: int64
# Department
# HR         2
# IT         2
# Finance    2
# Name: count, dtype: int64

# %%
# --- QUANTITATIVE ANALYSIS ---
print("\nQuantitative Analysis:")
print(df[['Age', 'Salary']].describe())  # Summary statistics

# Histogram for Age
df['Age'].plot(kind='hist', bins=5, color='skyblue', edgecolor='black')
plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.show()

# Scatter plot: Age vs Salary
plt.scatter(df['Age'], df['Salary'], color='green')
plt.title("Age vs Salary")
plt.xlabel("Age")
plt.ylabel("Salary")
plt.show()
# Out:
# Quantitative Analysis:
#              Age        Salary
# count   6.000000      6.000000
# mean   30.000000  58333.333333
# std     9.486833  12659.647178
# min    18.000000  40000.000000
# 25%    23.250000  51250.000000
# 50%    31.000000  58500.000000
# 75%    34.250000  66500.000000
# max    44.000000  75000.000000
